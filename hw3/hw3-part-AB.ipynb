# %%
# Download the data
# !wget https://people.cs.pitt.edu/~mzhang/cs1699/pacs_dataset.zip
# !unzip pacs_dataset.zip
# Out:
# --2024-03-05 15:02:14--  https://people.cs.pitt.edu/~mzhang/cs1699/pacs_dataset.zip
# Resolving people.cs.pitt.edu (people.cs.pitt.edu)... 136.142.35.172
# Connecting to people.cs.pitt.edu (people.cs.pitt.edu)|136.142.35.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184357302 (176M) [application/zip]
# Saving to: ‘pacs_dataset.zip’
#
# pacs_dataset.zip    100%[===================>] 175.82M  7.27MB/s    in 23s
#
# 2024-03-05 15:02:37 (7.80 MB/s) - ‘pacs_dataset.zip’ saved [184357302/184357302]
#
# Archive:  pacs_dataset.zip
#    creating: pacs_dataset/
#    creating: pacs_dataset/train/
#    creating: pacs_dataset/train/art_painting/
#    creating: pacs_dataset/train/art_painting/dog/
#   inflating: pacs_dataset/train/art_painting/dog/pic_002.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_004.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_005.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_006.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_007.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_008.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_009.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_010.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_011.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_012.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_014.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_015.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_016.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_017.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_018.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_019.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_020.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_021.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_022.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_023.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_024.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_026.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_027.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_028.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_029.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_031.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_032.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_033.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_034.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_035.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_036.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_038.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_039.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_040.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_041.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_042.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_043.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_045.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_046.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_047.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_048.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_049.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_050.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_051.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_052.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_053.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_054.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_055.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_056.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_057.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_058.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_059.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_060.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_061.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_062.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_063.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_064.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_065.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_066.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_067.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_070.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_072.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_073.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_074.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_075.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_076.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_077.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_078.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_079.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_080.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_081.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_082.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_083.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_084.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_085.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_086.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_087.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_088.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_089.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_091.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_094.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_095.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_097.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_098.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_099.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_100.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_101.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_102.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_103.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_104.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_105.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_106.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_107.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_108.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_109.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_110.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_113.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_114.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_116.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_117.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_118.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_120.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_121.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_124.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_126.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_127.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_130.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_131.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_132.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_133.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_134.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_135.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_136.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_137.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_139.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_140.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_143.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_144.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_145.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_146.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_147.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_148.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_149.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_150.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_151.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_152.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_153.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_154.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_156.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_157.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_158.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_161.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_163.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_164.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_165.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_166.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_167.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_168.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_169.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_170.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_172.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_173.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_174.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_176.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_177.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_178.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_179.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_180.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_181.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_182.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_183.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_184.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_185.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_186.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_187.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_188.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_191.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_192.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_193.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_195.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_197.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_198.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_199.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_200.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_201.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_202.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_203.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_204.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_205.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_206.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_208.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_209.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_210.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_211.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_212.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_213.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_214.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_215.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_217.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_219.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_220.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_222.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_223.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_224.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_225.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_226.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_227.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_228.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_229.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_230.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_231.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_232.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_233.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_234.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_236.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_237.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_238.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_239.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_240.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_241.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_242.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_243.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_245.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_246.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_247.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_248.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_249.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_250.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_251.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_252.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_253.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_254.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_255.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_256.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_257.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_258.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_259.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_260.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_261.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_262.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_264.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_265.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_266.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_267.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_268.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_269.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_271.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_272.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_274.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_275.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_276.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_278.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_279.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_280.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_281.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_282.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_283.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_284.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_285.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_287.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_288.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_289.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_290.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_291.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_292.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_293.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_294.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_295.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_296.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_297.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_298.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_299.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_300.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_301.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_303.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_304.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_305.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_306.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_307.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_309.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_310.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_311.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_312.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_313.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_314.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_315.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_316.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_317.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_318.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_319.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_320.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_322.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_323.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_324.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_325.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_326.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_327.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_328.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_329.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_330.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_331.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_332.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_333.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_334.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_335.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_337.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_338.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_339.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_340.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_341.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_342.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_343.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_344.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_346.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_348.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_349.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_350.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_352.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_353.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_354.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_355.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_357.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_358.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_359.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_360.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_361.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_362.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_365.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_366.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_367.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_368.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_369.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_370.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_371.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_372.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_374.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_375.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_377.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_378.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_380.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_381.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_382.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_383.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_384.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_386.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_387.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_388.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_390.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_391.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_392.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_394.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_395.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_397.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_398.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_399.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_400.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_401.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_404.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_405.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_406.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_407.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_408.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_409.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_410.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_411.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_413.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_414.jpg
#   inflating: pacs_dataset/train/art_painting/dog/pic_415.jpg
#    creating: pacs_dataset/train/art_painting/elephant/
#   inflating: pacs_dataset/train/art_painting/elephant/pic_002.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_003.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_004.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_005.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_006.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_007.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_008.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_009.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_011.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_012.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_014.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_015.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_016.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_017.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_018.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_019.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_020.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_021.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_022.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_023.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_024.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_025.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_026.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_027.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_028.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_029.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_030.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_031.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_032.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_033.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_034.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_036.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_037.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_039.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_040.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_041.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_043.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_044.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_045.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_046.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_048.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_049.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_051.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_052.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_053.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_054.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_055.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_056.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_057.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_058.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_059.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_060.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_061.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_062.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_063.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_064.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_065.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_066.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_067.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_068.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_071.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_072.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_073.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_074.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_075.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_076.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_077.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_078.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_079.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_080.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_081.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_082.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_083.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_084.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_085.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_086.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_087.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_088.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_089.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_090.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_091.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_092.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_093.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_094.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_095.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_096.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_098.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_099.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_100.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_101.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_102.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_104.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_105.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_106.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_107.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_108.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_110.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_111.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_113.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_114.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_115.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_118.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_119.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_120.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_121.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_122.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_123.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_124.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_125.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_126.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_128.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_129.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_130.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_131.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_132.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_133.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_134.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_135.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_136.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_137.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_138.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_139.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_140.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_141.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_142.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_143.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_144.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_145.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_147.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_149.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_150.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_151.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_152.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_153.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_154.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_155.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_157.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_158.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_159.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_160.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_162.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_163.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_164.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_166.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_167.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_168.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_170.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_171.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_172.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_173.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_174.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_175.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_176.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_177.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_178.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_179.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_181.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_182.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_183.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_184.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_185.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_186.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_187.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_188.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_189.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_190.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_191.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_192.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_193.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_194.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_195.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_196.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_198.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_199.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_200.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_201.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_202.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_204.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_205.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_206.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_207.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_208.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_209.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_211.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_212.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_213.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_214.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_215.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_217.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_218.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_220.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_221.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_222.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_224.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_225.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_226.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_227.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_228.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_229.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_230.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_231.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_232.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_233.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_234.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_235.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_236.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_237.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_238.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_239.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_240.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_241.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_242.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_243.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_244.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_246.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_249.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_250.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_251.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_252.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_253.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_254.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_256.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_257.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_258.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_259.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_260.jpg
#   inflating: pacs_dataset/train/art_painting/elephant/pic_261.jpg
#    creating: pacs_dataset/train/art_painting/giraffe/
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_001.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_002.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_003.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_004.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_005.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_007.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_008.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_009.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_010.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_011.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_012.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_013.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_014.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_016.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_017.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_018.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_019.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_020.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_021.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_022.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_023.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_024.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_025.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_026.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_027.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_029.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_030.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_031.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_032.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_033.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_034.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_035.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_036.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_037.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_039.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_040.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_041.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_042.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_043.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_044.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_045.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_046.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_047.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_048.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_049.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_050.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_051.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_052.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_053.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_054.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_055.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_056.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_057.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_058.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_059.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_060.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_061.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_062.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_063.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_065.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_068.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_069.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_071.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_072.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_073.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_074.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_075.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_077.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_078.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_079.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_081.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_082.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_083.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_084.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_086.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_087.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_088.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_089.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_091.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_093.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_094.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_095.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_096.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_097.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_098.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_099.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_100.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_101.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_102.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_103.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_104.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_105.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_106.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_107.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_108.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_109.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_111.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_112.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_113.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_114.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_115.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_116.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_117.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_118.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_119.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_120.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_121.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_122.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_123.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_126.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_127.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_128.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_129.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_131.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_132.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_133.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_134.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_135.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_136.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_137.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_138.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_139.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_140.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_141.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_142.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_143.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_144.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_145.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_146.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_147.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_150.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_151.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_152.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_153.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_154.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_155.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_157.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_158.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_159.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_160.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_161.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_162.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_163.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_164.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_165.jpg
#   inflating: pacs_dataset/train/art_painting/giraffe/pic_166.jpg
# ...
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6511-1.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6611-5.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6611-9.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6661-2.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6661-3.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6784-4.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_6937-2.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_7031-7.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_7083-4.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_759-5.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_7592-2.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_7592-3.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_8222-4.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_8518-6.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_8571-2.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_86-1.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_8757-5.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_8901-1.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_9043-7.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_9237-6.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_9270-6.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_9270-9.png
#   inflating: pacs_dataset/val/sketch/elephant/n02503517_9827-7.png
#    creating: pacs_dataset/val/sketch/giraffe/
#   inflating: pacs_dataset/val/sketch/giraffe/7365.png
#   inflating: pacs_dataset/val/sketch/giraffe/7396.png
#   inflating: pacs_dataset/val/sketch/giraffe/7407.png
#   inflating: pacs_dataset/val/sketch/giraffe/7408.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10130-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10130-5.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10295-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10453-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10491-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10491-6.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10541-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10616-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10616-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_10802-5.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11130-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11215-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11273-6.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11328-6.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11458-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11487-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11666-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11666-5.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11683-7.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_11894-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_12059-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_12413-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_12930-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_12930-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_13430-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_13868-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14040-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14121-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14121-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14121-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14148-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14184-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14554-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14724-5.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14781-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14784-6.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14846-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14872-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_14885-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_15005-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_15479-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_15936-7.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_16085-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_16483-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_2677-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_2677-6.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_376-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_376-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_3944-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_3944-10.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_3944-6.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_5004-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_569-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_628-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_6552-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_6552-5.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_67-7.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_866-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_8789-3.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_8846-10.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_8846-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_8875-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_8875-8.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_9261-2.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_9398-4.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_9472-9.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_9719-1.png
#   inflating: pacs_dataset/val/sketch/giraffe/n02439033_991-8.png
#    creating: pacs_dataset/val/sketch/guitar/
#   inflating: pacs_dataset/val/sketch/guitar/7606.png
#   inflating: pacs_dataset/val/sketch/guitar/7613.png
#   inflating: pacs_dataset/val/sketch/guitar/7648.png
#   inflating: pacs_dataset/val/sketch/guitar/7651.png
#   inflating: pacs_dataset/val/sketch/guitar/7675.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_330-3.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_4605-6.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_5134-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_5134-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_5489-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_6560-3.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_659-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_6704-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_7770-3.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_8268-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_8618-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_8820-3.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_8859-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_9243-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_9243-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_9254-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_9661-3.png
#   inflating: pacs_dataset/val/sketch/guitar/n02676566_970-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_12468-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_1708-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_1708-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_6255-5.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_6650-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_6662-6.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_6718-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_6718-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03272010_6926-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_11020-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_21782-2.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_21782-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_21884-1.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_22785-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_22785-5.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_23229-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_23229-5.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_24525-3.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_24525-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_3203-4.png
#   inflating: pacs_dataset/val/sketch/guitar/n03467517_8929-3.png
#    creating: pacs_dataset/val/sketch/horse/
#   inflating: pacs_dataset/val/sketch/horse/8482.png
#   inflating: pacs_dataset/val/sketch/horse/8504.png
#   inflating: pacs_dataset/val/sketch/horse/8517.png
#   inflating: pacs_dataset/val/sketch/horse/8519.png
#   inflating: pacs_dataset/val/sketch/horse/8520.png
#   inflating: pacs_dataset/val/sketch/horse/8521.png
#   inflating: pacs_dataset/val/sketch/horse/8524.png
#   inflating: pacs_dataset/val/sketch/horse/8534.png
#   inflating: pacs_dataset/val/sketch/horse/8537.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_10081-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_10081-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_10761-7.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_11479-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_11483-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_1189-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12128-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12128-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12174-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12200-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12230-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12328-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_1234-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_12418-9.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_13132-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_13132-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_13136-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_13159-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_13718-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_13718-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_14233-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_1443-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_1443-7.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_1443-8.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_14846-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_14846-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_14846-7.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_15440-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_15440-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_15440-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_15453-7.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_16194-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_16358-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_16948-8.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_1695-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_17043-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_17634-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_18570-7.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2233-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2248-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2372-7.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_245-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_257-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_257-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2616-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2733-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_276-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2825-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2825-8.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_2846-8.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_3388-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_3388-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_3808-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_3808-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_468-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_4795-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_4795-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_54-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_54-2.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_54-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_54-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_6192-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_7631-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_777-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_779-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_8718-6.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_8744-5.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_8806-1.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_8806-4.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_9064-3.png
#   inflating: pacs_dataset/val/sketch/horse/n02374451_929-5.png
#    creating: pacs_dataset/val/sketch/house/
#   inflating: pacs_dataset/val/sketch/house/8805.png
#   inflating: pacs_dataset/val/sketch/house/8827.png
#   inflating: pacs_dataset/val/sketch/house/8858.png
#   inflating: pacs_dataset/val/sketch/house/8871.png
#   inflating: pacs_dataset/val/sketch/house/8880.png
#    creating: pacs_dataset/val/sketch/person/
#   inflating: pacs_dataset/val/sketch/person/12081.png
#   inflating: pacs_dataset/val/sketch/person/12092.png
#   inflating: pacs_dataset/val/sketch/person/12124.png
#   inflating: pacs_dataset/val/sketch/person/12127.png
#   inflating: pacs_dataset/val/sketch/person/12155.png
#   inflating: pacs_dataset/val/sketch/person/12167.png
#   inflating: pacs_dataset/val/sketch/person/12182.png
#   inflating: pacs_dataset/val/sketch/person/12185.png
#   inflating: pacs_dataset/val/sketch/person/12189.png
#   inflating: pacs_dataset/val/sketch/person/12192.png
#   inflating: pacs_dataset/val/sketch/person/12203.png
#   inflating: pacs_dataset/val/sketch/person/12204.png
#   inflating: pacs_dataset/val/sketch/person/12208.png
#   inflating: pacs_dataset/val/sketch/person/12222.png
#   inflating: pacs_dataset/val/sketch/person/12224.png
#   inflating: pacs_dataset/val/sketch/person/12234.png
#   inflating: pacs_dataset/val/sketch/person/12239.png

# %%
# %matplotlib notebook
import sys, os, copy, collections
import numpy as np
import pandas as pd
from skimage import io

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

torch.cuda.is_available()
# Out:
# True

# %%
# default configuration
task_type = 'training'
experiment_name = 'exp'
label_type = 'domain'
learning_rate = 1e-3
weight_decay = 0
batch_size = 128
epochs = 5
LABEL_SIZE = {'domain': 4, 'category': 7}

# %%
class PACSDataset(Dataset):

    def __init__(
        self,
        root_dir,
        label_type='domain',
        is_train=False,
        transform=None
    ):
        self.root_dir = os.path.join(root_dir, 'train' if is_train else 'val')
        self.label_type = label_type
        self.is_train = is_train
        
        if transform:
            self.transform = transform
        else:
            self.transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.7659, 0.7463, 0.7173],
                    std=[0.3089, 0.3181, 0.3470]
                ),
            ])

        self.dataset, self.label_list = self.initialize_dataset()
        self.label_to_id = {x: i for i, x in enumerate(self.label_list)}
        self.id_to_label = {i: x for i, x in enumerate(self.label_list)}

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        label_id = self.label_to_id[label]
        image = self.transform(image)
        return image, label_id

    def initialize_dataset(self):
        
        assert os.path.isdir(self.root_dir), \
            f'`root_dir` is not found at {self.root_dir}'

        dataset = []
        domain_set = set()
        category_set = set()
        count = 0

        for root, dirs, files in os.walk(self.root_dir, topdown=True):
            if files:
                _, domain, category = root.rsplit('/', maxsplit=2)
                domain_set.add(domain)
                category_set.add(category)
                pbar = tqdm(files)
                for name in pbar:
                    pbar.set_description(
                        f'Processing Folder: domain={domain}, category={category}'
                    )
                    img_array = io.imread(os.path.join(root, name))
                    dataset.append((img_array, domain, category))

        images, domains, categories = zip(*dataset)

        if self.label_type == 'domain':
            labels = sorted(domain_set)
            dataset = list(zip(images, domains))
        elif self.label_type == 'category':
            labels = sorted(category_set)
            dataset = list(zip(images, categories))
        else:
            raise ValueError(
                'Unknown `label_type`: Expecting `domain` or `category`.'
            )

        return dataset, labels

# %%
# create datasets and data loaders
train_dataset = PACSDataset(
    root_dir='pacs_dataset', label_type=label_type, is_train=True
)
train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, num_workers=4
)
val_dataset = PACSDataset(
    root_dir='pacs_dataset', label_type=label_type, is_train=False
)
val_loader = DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, num_workers=4
)
# Out:
# Processing Folder: domain=sketch, category=giraffe: 100%|██████████| 681/681 [00:16<00:00, 40.28it/s]
# Processing Folder: domain=sketch, category=person: 100%|██████████| 143/143 [00:02<00:00, 47.71it/s]
# Processing Folder: domain=sketch, category=house: 100%|██████████| 75/75 [00:01<00:00, 62.37it/s]
# Processing Folder: domain=sketch, category=guitar: 100%|██████████| 564/564 [00:08<00:00, 69.81it/s]
# Processing Folder: domain=sketch, category=dog: 100%|██████████| 697/697 [00:15<00:00, 45.42it/s]
# Processing Folder: domain=sketch, category=horse: 100%|██████████| 736/736 [00:12<00:00, 59.48it/s]
# Processing Folder: domain=sketch, category=elephant: 100%|██████████| 674/674 [00:13<00:00, 50.86it/s]
# Processing Folder: domain=art_painting, category=giraffe: 100%|██████████| 254/254 [00:07<00:00, 32.96it/s]
# Processing Folder: domain=art_painting, category=person: 100%|██████████| 404/404 [00:09<00:00, 41.51it/s]
# Processing Folder: domain=art_painting, category=house: 100%|██████████| 262/262 [00:05<00:00, 52.20it/s]
# Processing Folder: domain=art_painting, category=guitar: 100%|██████████| 169/169 [00:05<00:00, 30.38it/s]
# Processing Folder: domain=art_painting, category=dog: 100%|██████████| 348/348 [00:09<00:00, 35.14it/s]
# Processing Folder: domain=art_painting, category=horse: 100%|██████████| 179/179 [00:04<00:00, 43.18it/s]
# Processing Folder: domain=art_painting, category=elephant: 100%|██████████| 227/227 [00:04<00:00, 46.96it/s]
# Processing Folder: domain=photo, category=giraffe: 100%|██████████| 165/165 [00:03<00:00, 44.60it/s]
# Processing Folder: domain=photo, category=person: 100%|██████████| 383/383 [00:08<00:00, 44.20it/s]
# Processing Folder: domain=photo, category=house: 100%|██████████| 243/243 [00:06<00:00, 38.45it/s]
# Processing Folder: domain=photo, category=guitar: 100%|██████████| 167/167 [00:04<00:00, 36.58it/s]
# Processing Folder: domain=photo, category=dog: 100%|██████████| 169/169 [00:04<00:00, 41.11it/s]
# Processing Folder: domain=photo, category=horse: 100%|██████████| 186/186 [00:06<00:00, 29.19it/s]
# Processing Folder: domain=photo, category=elephant: 100%|██████████| 181/181 [00:03<00:00, 49.39it/s]
# Processing Folder: domain=cartoon, category=giraffe: 100%|██████████| 314/314 [00:05<00:00, 61.75it/s]
# Processing Folder: domain=cartoon, category=person: 100%|██████████| 364/364 [00:06<00:00, 56.57it/s]
# Processing Folder: domain=cartoon, category=house: 100%|██████████| 266/266 [00:05<00:00, 46.82it/s]
# Processing Folder: domain=cartoon, category=guitar: 100%|██████████| 123/123 [00:02<00:00, 45.09it/s]
# Processing Folder: domain=cartoon, category=dog: 100%|██████████| 343/343 [00:06<00:00, 53.08it/s]
# Processing Folder: domain=cartoon, category=horse: 100%|██████████| 299/299 [00:05<00:00, 59.01it/s]
# Processing Folder: domain=cartoon, category=elephant: 100%|██████████| 411/411 [00:07<00:00, 53.57it/s]
# /ocean/projects/asc170022p/mtragoza/mambaforge/envs/CS2078/lib/python3.10/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Processing Folder: domain=sketch, category=giraffe: 100%|██████████| 72/72 [00:02<00:00, 34.08it/s]
# Processing Folder: domain=sketch, category=person: 100%|██████████| 17/17 [00:00<00:00, 26.61it/s]
# Processing Folder: domain=sketch, category=house: 100%|██████████| 5/5 [00:00<00:00, 43.63it/s]
# Processing Folder: domain=sketch, category=guitar: 100%|██████████| 44/44 [00:02<00:00, 21.12it/s]
# Processing Folder: domain=sketch, category=dog: 100%|██████████| 75/75 [00:03<00:00, 22.47it/s]
# Processing Folder: domain=sketch, category=horse: 100%|██████████| 80/80 [00:01<00:00, 68.11it/s]
# Processing Folder: domain=sketch, category=elephant: 100%|██████████| 66/66 [00:00<00:00, 68.49it/s]
# Processing Folder: domain=art_painting, category=giraffe: 100%|██████████| 31/31 [00:01<00:00, 27.80it/s]
# Processing Folder: domain=art_painting, category=person: 100%|██████████| 45/45 [00:01<00:00, 29.47it/s]
# Processing Folder: domain=art_painting, category=house: 100%|██████████| 33/33 [00:00<00:00, 49.61it/s]
# Processing Folder: domain=art_painting, category=guitar: 100%|██████████| 15/15 [00:00<00:00, 46.71it/s]
# Processing Folder: domain=art_painting, category=dog: 100%|██████████| 31/31 [00:00<00:00, 45.55it/s]
# Processing Folder: domain=art_painting, category=horse: 100%|██████████| 22/22 [00:00<00:00, 34.76it/s]
# Processing Folder: domain=art_painting, category=elephant: 100%|██████████| 28/28 [00:00<00:00, 35.57it/s]
# Processing Folder: domain=photo, category=giraffe: 100%|██████████| 17/17 [00:00<00:00, 34.92it/s]
# Processing Folder: domain=photo, category=person: 100%|██████████| 49/49 [00:01<00:00, 47.77it/s]
# Processing Folder: domain=photo, category=house: 100%|██████████| 37/37 [00:00<00:00, 61.46it/s]
# Processing Folder: domain=photo, category=guitar: 100%|██████████| 19/19 [00:00<00:00, 20.93it/s]
# Processing Folder: domain=photo, category=dog: 100%|██████████| 20/20 [00:00<00:00, 32.31it/s]
# Processing Folder: domain=photo, category=horse: 100%|██████████| 13/13 [00:00<00:00, 81.32it/s]
# Processing Folder: domain=photo, category=elephant: 100%|██████████| 21/21 [00:00<00:00, 31.06it/s]
# Processing Folder: domain=cartoon, category=giraffe: 100%|██████████| 32/32 [00:00<00:00, 68.73it/s]
# Processing Folder: domain=cartoon, category=person: 100%|██████████| 41/41 [00:00<00:00, 78.19it/s]
# Processing Folder: domain=cartoon, category=house: 100%|██████████| 22/22 [00:00<00:00, 63.78it/s]
# Processing Folder: domain=cartoon, category=guitar: 100%|██████████| 12/12 [00:00<00:00, 89.85it/s]
# Processing Folder: domain=cartoon, category=dog: 100%|██████████| 46/46 [00:01<00:00, 42.58it/s]
# Processing Folder: domain=cartoon, category=horse: 100%|██████████| 25/25 [00:00<00:00, 45.59it/s]
# Processing Folder: domain=cartoon, category=elephant: 100%|██████████| 46/46 [00:01<00:00, 36.92it/s]

# %%
class AlexNet(nn.Module):
    
    def __init__(self, config=None):
        super().__init__()
        self.config = config
        self.features = nn.Sequential(
            
            nn.Conv2d(3, 96, kernel_size=11, stride=4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=3, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(9216, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, LABEL_SIZE[label_type])
        )
        
    def forward(self, x):
        z = self.features(x).flatten(1)
        return self.classifier(z)

AlexNet().forward(torch.zeros(1, 3, 227, 227)).shape
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )

# %%
def model_training(model_class):

    best_model = None
    best_acc = 0.0

    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

    expt_name = 'experiments/{}/{}_lr_{}.wd_{}'.format(experiment_name, label_type, learning_rate, weight_decay)

    os.makedirs(expt_name, exist_ok=True)
    writer = SummaryWriter(log_dir=expt_name)

    configs = {'num_classes': LABEL_SIZE[label_type], 'dropout': 0.5}

    model = model_class(configs).to(device)

    print('Model Architecture:\n%s' % model)

    criterion = nn.CrossEntropyLoss(reduction='mean')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    try:
        for epoch in range(epochs):
            for phase in ('train', 'eval'):
                if phase == 'train':
                    model.train()
                    dataset = train_dataset
                    data_loader = train_loader
                else:
                    model.eval()
                    dataset = val_dataset
                    data_loader = val_loader

                running_loss = 0.0
                running_corrects = 0

                for step, (images, labels) in enumerate(tqdm(data_loader, file=sys.stdout)):
                    images = images.to(device)
                    labels = labels.to(device)

                    optimizer.zero_grad()

                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(images)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                            full_step = epoch * len(dataset) + step
                            writer.add_scalar('Loss/{}'.format(phase), loss.item(), full_step)

                    running_loss += loss.item() * images.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                epoch_loss = running_loss / len(dataset)
                epoch_acc = running_corrects.double() / len(dataset)
                writer.add_scalar('Epoch_Loss/{}'.format(phase), epoch_loss, epoch)
                writer.add_scalar('Epoch_Accuracy/{}'.format(phase), epoch_acc, epoch)
                print('[Epoch {}/{}] {} accuracy: {:.4f}, loss: {:.4f}'.format(
                    epoch+1, epochs, phase, epoch_acc, epoch_loss
                ))

                if phase == 'eval':
                    if epoch_acc > best_acc:
                        best_acc = epoch_acc
                        best_model = copy.deepcopy(model.state_dict())
                        torch.save(best_model, os.path.join(expt_name, 'best_model.pt'))

    except KeyboardInterrupt:
        pass

    return


model_training(AlexNet)
# Out:
# Model Architecture:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )
# 100%|██████████| 71/71 [00:26<00:00,  2.69it/s]
# [Epoch 1/5] train accuracy: 0.5693, loss: 1.1854
# 100%|██████████| 8/8 [00:04<00:00,  1.68it/s]
# [Epoch 1/5] eval accuracy: 0.7427, loss: 0.4846
# 100%|██████████| 71/71 [00:16<00:00,  4.36it/s]
# [Epoch 2/5] train accuracy: 0.7766, loss: 0.4579
# 100%|██████████| 8/8 [00:04<00:00,  1.70it/s]
# [Epoch 2/5] eval accuracy: 0.7770, loss: 0.4031
# 100%|██████████| 71/71 [00:16<00:00,  4.26it/s]
# [Epoch 3/5] train accuracy: 0.8138, loss: 0.4009
# 100%|██████████| 8/8 [00:05<00:00,  1.47it/s]
# [Epoch 3/5] eval accuracy: 0.8102, loss: 0.4997
# 100%|██████████| 71/71 [00:16<00:00,  4.36it/s]
# [Epoch 4/5] train accuracy: 0.7716, loss: 0.5637
# 100%|██████████| 8/8 [00:04<00:00,  1.88it/s]
# [Epoch 4/5] eval accuracy: 0.8195, loss: 0.3860
# 100%|██████████| 71/71 [00:16<00:00,  4.32it/s]
# [Epoch 5/5] train accuracy: 0.8305, loss: 0.3958
# 100%|██████████| 8/8 [00:04<00:00,  1.73it/s]
# [Epoch 5/5] eval accuracy: 0.8558, loss: 0.3573

# %% [markdown]
# # Part b - Enhanced AlexNet

# %%
class AlexNetLargerKernel(nn.Module):
    
    def __init__(self, config=None):
        super().__init__()
        self.config = config
        self.features = nn.Sequential(
            
            nn.Conv2d(3, 96, kernel_size=21, stride=8),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(96, 256, kernel_size=7, stride=2, padding=2),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, stride=2, padding=1),
            nn.ReLU(inplace=True)
        )
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(9216, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, LABEL_SIZE[label_type])
        )
        
    def forward(self, x):
        z = self.features(x).flatten(1)
        return self.classifier(z)

AlexNetLargerKernel().forward(torch.zeros(1, 3, 227, 227)).shape
# Out:
# torch.Size([1, 4])

# %%
model_training(AlexNetLargerKernel)
# Out:
# Model Architecture:
# AlexNetLargerKernel(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(21, 21), stride=(8, 8))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(96, 256, kernel_size=(7, 7), stride=(2, 2), padding=(2, 2))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (9): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )
# 100%|██████████| 71/71 [00:18<00:00,  3.81it/s]
# [Epoch 1/5] train accuracy: 0.6505, loss: 0.8296
# 100%|██████████| 8/8 [00:04<00:00,  1.85it/s]
# [Epoch 1/5] eval accuracy: 0.7749, loss: 0.5167
# 100%|██████████| 71/71 [00:15<00:00,  4.61it/s]
# [Epoch 2/5] train accuracy: 0.7832, loss: 0.4833
# 100%|██████████| 8/8 [00:04<00:00,  1.77it/s]
# [Epoch 2/5] eval accuracy: 0.8164, loss: 0.4563
# 100%|██████████| 71/71 [00:15<00:00,  4.57it/s]
# [Epoch 3/5] train accuracy: 0.8167, loss: 0.4326
# 100%|██████████| 8/8 [00:04<00:00,  1.72it/s]
# [Epoch 3/5] eval accuracy: 0.8039, loss: 0.4714
# 100%|██████████| 71/71 [00:22<00:00,  3.23it/s]
# [Epoch 4/5] train accuracy: 0.7892, loss: 0.5811
# 100%|██████████| 8/8 [00:07<00:00,  1.03it/s]
# [Epoch 4/5] eval accuracy: 0.8195, loss: 0.4107
# 100%|██████████| 71/71 [00:16<00:00,  4.35it/s]
# [Epoch 5/5] train accuracy: 0.8191, loss: 0.4453
# 100%|██████████| 8/8 [00:04<00:00,  1.61it/s]
# [Epoch 5/5] eval accuracy: 0.8008, loss: 0.4299

# %%
class AlexNetAvgPooling(nn.Module):
    
    def __init__(self, config=None):
        super().__init__()
        self.config = config
        self.features = nn.Sequential(
            
            nn.Conv2d(3, 96, kernel_size=11, stride=4),
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.ReLU(inplace=True),
            nn.AvgPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            
            nn.AvgPool2d(kernel_size=3, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(9216, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, LABEL_SIZE[label_type])
        )
        
    def forward(self, x):
        z = self.features(x).flatten(1)
        return self.classifier(z)

AlexNetAvgPooling().forward(torch.zeros(1, 3, 227, 227)).shape
# Out:
# torch.Size([1, 4])

# %%
model_training(AlexNetAvgPooling)
# Out:
# Model Architecture:
# AlexNetAvgPooling(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): AvgPool2d(kernel_size=3, stride=2, padding=0)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): AvgPool2d(kernel_size=3, stride=2, padding=0)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): AvgPool2d(kernel_size=3, stride=2, padding=0)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )
# 100%|██████████| 71/71 [00:16<00:00,  4.23it/s]
# [Epoch 1/5] train accuracy: 0.6201, loss: 0.8376
# 100%|██████████| 8/8 [00:06<00:00,  1.21it/s]
# [Epoch 1/5] eval accuracy: 0.7510, loss: 0.4992
# 100%|██████████| 71/71 [00:16<00:00,  4.36it/s]
# [Epoch 2/5] train accuracy: 0.8014, loss: 0.4557
# 100%|██████████| 8/8 [00:04<00:00,  1.84it/s]
# [Epoch 2/5] eval accuracy: 0.7946, loss: 0.5237
# 100%|██████████| 71/71 [00:16<00:00,  4.31it/s]
# [Epoch 3/5] train accuracy: 0.8230, loss: 0.4402
# 100%|██████████| 8/8 [00:04<00:00,  1.68it/s]
# [Epoch 3/5] eval accuracy: 0.8133, loss: 0.4092
# 100%|██████████| 71/71 [00:16<00:00,  4.32it/s]
# [Epoch 4/5] train accuracy: 0.8512, loss: 0.3641
# 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# [Epoch 4/5] eval accuracy: 0.8641, loss: 0.3215
# 100%|██████████| 71/71 [00:27<00:00,  2.60it/s]
# [Epoch 5/5] train accuracy: 0.8534, loss: 0.3579
# 100%|██████████| 8/8 [00:04<00:00,  1.79it/s]
# [Epoch 5/5] eval accuracy: 0.8610, loss: 0.3560
